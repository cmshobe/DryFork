# %% [markdown]
# Dealing with break strength data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
all_breaks = pd.read_csv('AllBreakData.csv')
all_breaks = all_breaks[all_breaks['Is50MPa'] != '#VALUE!']
all_breaks['Is50MPa'] = all_breaks['Is50MPa'].astype(float)

# %%
all_breaks
# Out:
#     Lithology SampleID SampleLabel  3breaks  RebreakNumber  length  width  \
# 0          C1     C1-1        C1-1        1              0     6.5    7.2
# 1          C1    C1-10       C1-10        1              0     6.7    5.1
# 2          C1    C1-11       C1-11        0              0     7.5    4.2
# 3          C1    C1-12       C1-12        0              0     6.9    5.5
# 4          C1    C1-13       C1-13        0              0     7.2    4.9
# ..        ...      ...         ...      ...            ...     ...    ...
# 177       SS2    SS2-6     SS2-6-1        0              1     4.9    2.2
# 178       SS2    SS2-7     SS2-7-1        0              1     6.1    3.9
# 179       SS2    SS2-8     SS2-8-1        1              1     4.2    2.4
# 180       SS2    SS2-8     SS2-8-2        1              1     4.6    4.5
# 181       SS2    SS2-9     SS2-9-1        0              1     5.1    2.7
#
#      height      A      De2m  ...  LoadNormaltoBed?   LMPa  Cup Weight  \
# 0       3.1  22.32  0.002842  ...               1.0  12.67       27.65
# 1       2.9  14.79  0.001883  ...               1.0    5.5         NaN
# 2       3.8  15.96  0.002032  ...               1.0   4.87         NaN
# 3       2.9  15.95  0.002031  ...               1.0   1.09         NaN
# 4       3.7  18.13  0.002308  ...               1.0   2.68         NaN
# ..      ...    ...       ...  ...               ...    ...         ...
# 177     3.6   7.92  0.001008  ...               0.0   7.63         NaN
# 178     3.7  14.43  0.001837  ...               0.0   6.16         NaN
# 179     3.2   7.68  0.000978  ...               1.0    6.6         NaN
# 180     3.8  17.10  0.002177  ...               0.0   6.19         NaN
# 181     2.5   6.75  0.000859  ...               1.0   6.08         NaN
#
#                                                  Notes         PKN  \
# 0                                                  NaN  0.01201116
# 1                                                  NaN    0.005214
# 2    broke slowly, difficult to tell when first fra...  0.00461676
# 3    broke on first pump, wet surfade shows pre-exi...  0.00103332
# 4    broke on second pump, wet surfaces show pre-ex...  0.00254064
# ..                                                 ...         ...
# 177                                                NaN  0.00723324
# 178                                                NaN  0.00583968
# 179                                                NaN   0.0062568
# 180                                                NaN  0.00586812
# 181                                                NaN  0.00576384
#
#     CorrectionFactor (F)        IsMPa   Is50MPa Unnamed: 25  Piston Area (A)
# 0               1.029259  4.226494192  4.350156         NaN           1000.0
# 1               0.938234   2.76880498  2.597787         NaN              NaN
# 2               0.954445  2.271924663  2.168426         NaN              NaN
# 3               0.954310  0.508819401  0.485571         NaN              NaN
# 4               0.982218  1.100613516  1.081042         NaN              NaN
# ..                   ...          ...       ...         ...              ...
# 177             0.815233  7.172940168  5.847614         NaN              NaN
# 178             0.933046  3.178426939  2.965620         NaN              NaN
# 179             0.809608  6.398535258  5.180303         NaN              NaN
# 180             0.969376  2.695208642  2.612672         NaN              NaN
# 181             0.786433  6.706526706  5.274234         NaN              NaN
#
# [177 rows x 27 columns]

# %%
carb = all_breaks.loc[(all_breaks['Lithology'] == 'C1') | (all_breaks['Lithology'] == 'C2') | (all_breaks['Lithology'] == 'C3') | (all_breaks['Lithology'] == 'C4')]
c1 = all_breaks.loc[(all_breaks['Lithology'] == 'C1')]
c2 = all_breaks.loc[(all_breaks['Lithology'] == 'C2')]
c3 = all_breaks.loc[(all_breaks['Lithology'] == 'C3')]
c4 = all_breaks.loc[(all_breaks['Lithology'] == 'C4')]

# %%
clast = all_breaks.loc[(all_breaks['Lithology'] == 'SS1') | (all_breaks['Lithology'] == 'SS2')]
coarse =  all_breaks.loc[(all_breaks['Lithology'] == 'SS2')]

# %%
coarse
# Out:
#     Lithology SampleID SampleLabel  3breaks  RebreakNumber  length  width  \
# 149       SS2    SS2-1       SS2-1        1              0     5.9    8.3
# 150       SS2   SS2-10      SS2-10        1              0     6.5    5.8
# 151       SS2   SS2-11      SS2-11        1              0     6.6    6.2
# 152       SS2   SS2-12      SS2-12        0              0     6.1    4.0
# 153       SS2   SS2-13      SS2-13        1              0     6.0    3.7
# 154       SS2    SS2-2       SS2-2        0              0     5.3    6.9
# 155       SS2    SS2-3       SS2-3        1              0     7.5    4.5
# 156       SS2    SS2-4       SS2-4        1              0     7.9    4.6
# 157       SS2    SS2-5       SS2-5        0              0     6.7    5.1
# 158       SS2    SS2-6       SS2-6        0              0     4.9    4.4
# 159       SS2    SS2-7       SS2-7        0              0     6.8    3.8
# 160       SS2    SS2-8       SS2-8        1              0     4.3    4.6
# 161       SS2    SS2-9       SS2-9        0              0     4.7    4.8
# 162       SS2    SS2-1     SS2-1-1        1              1     7.4    3.1
# 163       SS2    SS2-1     SS2-1-2        1              1     4.9    2.1
# 164       SS2   SS2-10    SS2-10-1        1              1     6.5    5.8
# 165       SS2   SS2-10    SS2-10-2        1              1     6.1    4.4
# 166       SS2   SS2-11    SS2-11-1        1              1     6.4    4.4
# 167       SS2   SS2-11    SS2-11-2        1              1     6.8    3.5
# 168       SS2   SS2-12    SS2-12-1        0              1     6.1    3.9
# 169       SS2   SS2-13    SS2-13-1        1              1     3.5    2.7
# 170       SS2   SS2-13    SS2-13-2        1              1     5.1    3.4
# 171       SS2    SS2-2     SS2-2-1        0              1     4.3    3.4
# 172       SS2    SS2-3     SS2-3-1        1              1     4.9    3.0
# 173       SS2    SS2-3     SS2-3-2        1              1     4.5    3.3
# 174       SS2    SS2-4     SS2-4-1        1              1     4.7    3.9
# 175       SS2    SS2-4     SS2-4-2        1              1     5.8    3.9
# 176       SS2    SS2-5     SS2-5-1        0              1     6.3    5.1
# 177       SS2    SS2-6     SS2-6-1        0              1     4.9    2.2
# 178       SS2    SS2-7     SS2-7-1        0              1     6.1    3.9
# 179       SS2    SS2-8     SS2-8-1        1              1     4.2    2.4
# 180       SS2    SS2-8     SS2-8-2        1              1     4.6    4.5
# 181       SS2    SS2-9     SS2-9-1        0              1     5.1    2.7
#
#      height      A      De2m  ...  LoadNormaltoBed?   LMPa  Cup Weight  \
# 149     3.0  24.90  0.003170  ...               1.0   5.93         NaN
# 150     2.9  16.82  0.002142  ...               1.0   8.21         NaN
# 151     3.1  19.22  0.002447  ...               1.0  12.39         NaN
# 152     3.8  15.20  0.001935  ...               1.0   4.03         NaN
# 153     3.7  13.69  0.001743  ...               1.0  12.96         NaN
# 154     3.1  21.39  0.002723  ...               1.0   7.84         NaN
# 155     3.3  14.85  0.001891  ...               1.0  11.26         NaN
# 156     3.9  17.94  0.002284  ...               1.0  10.57         NaN
# 157     2.5  12.75  0.001623  ...               1.0   7.63         NaN
# 158     3.6  15.84  0.002017  ...               1.0   6.39         NaN
# 159     3.7  14.06  0.001790  ...               1.0   4.72         NaN
# 160     4.1  18.86  0.002401  ...               1.0  12.88         NaN
# 161     2.6  12.48  0.001589  ...               1.0  11.61         NaN
# 162     3.1   9.61  0.001224  ...               1.0   9.65         NaN
# 163     2.6   5.46  0.000695  ...               0.0   5.62         NaN
# 164     2.8  16.24  0.002068  ...               1.0   7.49         NaN
# 165     1.8   7.92  0.001008  ...               1.0   3.66         NaN
# 166     2.2   9.68  0.001232  ...               1.0   6.63         NaN
# 167     2.4   8.40  0.001070  ...               1.0   4.84         NaN
# 168     3.7  14.43  0.001837  ...               1.0   9.53         NaN
# 169     3.3   8.91  0.001134  ...               0.0   7.03         NaN
# 170     3.6  12.24  0.001558  ...               0.0   8.09         NaN
# 171     3.6  12.24  0.001558  ...               1.0   5.85         NaN
# 172     3.5  10.50  0.001337  ...               0.0   5.56         NaN
# 173     3.5  11.55  0.001471  ...               0.0   6.05         NaN
# 174     3.5  13.65  0.001738  ...               1.0   7.66         NaN
# 175     3.6  14.04  0.001788  ...               1.0   3.86         NaN
# 176     2.4  12.24  0.001558  ...               1.0   8.38         NaN
# 177     3.6   7.92  0.001008  ...               0.0   7.63         NaN
# 178     3.7  14.43  0.001837  ...               0.0   6.16         NaN
# 179     3.2   7.68  0.000978  ...               1.0    6.6         NaN
# 180     3.8  17.10  0.002177  ...               0.0   6.19         NaN
# 181     2.5   6.75  0.000859  ...               1.0   6.08         NaN
#
#                              Notes         PKN CorrectionFactor (F)  \
# 149  spalled from bottom of sample  0.00562164             1.054905
# 150                            NaN  0.00778308             0.965782
# 151                            NaN  0.01174572             0.995206
# 152  spalled from bottom of sample  0.00382044             0.944024
# 153                            NaN  0.01228608             0.922060
# 154                            NaN  0.00743232             1.019450
# 155                            NaN  0.01067448             0.939089
# 156                            NaN  0.01002036             0.979892
# 157            broke chip off edge  0.00723324             0.907420
# 158                            NaN  0.00605772             0.952825
# 159           broke chip from edge  0.00447456             0.927609
# 160                            NaN  0.01221024             0.990981
# 161                            NaN  0.01100628             0.903060
# 162                            NaN   0.0091482             0.851493
# 163                            NaN  0.00532776             0.749785
# 164                            NaN  0.00710052             0.958187
# 165                            NaN  0.00346968             0.815233
# 166                            NaN  0.00628524             0.852885
# 167                            NaN  0.00458832             0.826097
# 168                            NaN  0.00903444             0.933046
# 169                            NaN  0.00666444             0.837126
# 170                            NaN  0.00766932             0.899123
# 171                            NaN   0.0055458             0.899123
# 172                            NaN  0.00527088             0.868632
# 173                            NaN   0.0057354             0.887461
# 174                            NaN  0.00726168             0.921453
# 175                            NaN  0.00365928             0.927312
# 176                            NaN  0.00794424             0.899123
# 177                            NaN  0.00723324             0.815233
# 178                            NaN  0.00583968             0.933046
# 179                            NaN   0.0062568             0.809608
# 180                            NaN  0.00586812             0.969376
# 181                            NaN  0.00576384             0.786433
#
#            IsMPa   Is50MPa Unnamed: 25  Piston Area (A)
# 149  1.773181527  1.870537         NaN              NaN
# 150  3.634251828  3.509896         NaN              NaN
# 151  4.799718587  4.776707         NaN              NaN
# 152   1.97405528  1.863556         NaN              NaN
# 153   7.04854384  6.499180         NaN              NaN
# 154  2.728997451  2.782076         NaN              NaN
# 155  5.645595896  5.301718         NaN              NaN
# 156  4.386825916  4.298618         NaN              NaN
# 157  4.455661657  4.043155         NaN              NaN
# 158  3.003609939  2.861915         NaN              NaN
# 159  2.499507993  2.318567         NaN              NaN
# 160  5.084778351  5.038918         NaN              NaN
# 161  6.926526279  6.255069         NaN              NaN
# 162  7.476559219  6.366238         NaN              NaN
# 163  7.663753452  5.746167         NaN              NaN
# 164  3.433947449  3.290363         NaN              NaN
# 165  3.440755048  2.805016         NaN              NaN
# 166  5.099598949  4.349370         NaN              NaN
# 167  4.290065544  3.544012         NaN              NaN
# 168  4.917274144  4.588045         NaN              NaN
# 169  5.874561745  4.917748         NaN              NaN
# 170  4.921131336  4.424703         NaN              NaN
# 171  3.558543673  3.199569         NaN              NaN
# 172   3.94260569  3.424674         NaN              NaN
# 173  3.900059586  3.461151         NaN              NaN
# 174  4.178245654  3.850057         NaN              NaN
# 175  2.047000971  1.898209         NaN              NaN
# 176  5.097537774  4.583314         NaN              NaN
# 177  7.172940168  5.847614         NaN              NaN
# 178  3.178426939  2.965620         NaN              NaN
# 179  6.398535258  5.180303         NaN              NaN
# 180  2.695208642  2.612672         NaN              NaN
# 181  6.706526706  5.274234         NaN              NaN
#
# [33 rows x 27 columns]

# %%
fine = all_breaks.loc[(all_breaks['Lithology'] == 'SS1')]

# %%
fine
# Out:
#     Lithology SampleID SampleLabel  3breaks  RebreakNumber  length  width  \
# 124       SS1    SS1-1       SS1-1        0              0     8.9    6.7
# 125       SS1   SS1-10      SS1-10        1              0     6.6    3.3
# 126       SS1    SS1-2       SS1-2        1              0     6.4    5.8
# 127       SS1    SS1-3       SS1-3        1              0    10.0    6.9
# 128       SS1    SS1-4       SS1-4        0              0     9.8    7.0
# 129       SS1    SS1-5       SS1-5        1              0    11.2    9.2
# 130       SS1    SS1-6       SS1-6        0              0    10.9    8.1
# 131       SS1    SS1-7       SS1-7        1              0     9.4    7.4
# 132       SS1    SS1-8       SS1-8        0              0     7.1    6.4
# 133       SS1    SS1-9       SS1-9        1              0     7.7    4.6
# 134       SS1    SS1-1     SS1-1-1        0              1     8.1    5.1
# 135       SS1   SS1-10    SS1-10-1        1              1     6.1    3.3
# 136       SS1   SS1-10    SS1-10-2        1              1     5.7    3.3
# 137       SS1    SS1-2     SS1-2-1        1              1     7.2    4.6
# 138       SS1    SS1-2     SS1-2-2        1              1     7.9    3.9
# 139       SS1    SS1-3     SS1-3-1        1              1     9.5    3.2
# 140       SS1    SS1-3     SS1-3-2        1              1     9.3    4.9
# 141       SS1    SS1-4     SS1-4-1        0              1    10.1    5.9
# 142       SS1    SS1-5     SS1-5-1        1              1    11.2    4.1
# 143       SS1    SS1-5     SS1-5-2        1              1    10.6    5.1
# 144       SS1    SS1-6     SS1-6-1        0              1     8.8    5.4
# 145       SS1    SS1-7     SS1-7-1        1              1     9.6    3.6
# 146       SS1    SS1-7     SS1-7-2        1              1     9.4    2.9
# 148       SS1    SS1-9     SS1-9-2        1              1     4.5    3.9
#
#      height      A      De2m  ...  LoadNormaltoBed?   LMPa  Cup Weight  Notes  \
# 124     4.6  30.82  0.003924  ...               1.0  20.28         NaN    NaN
# 125     3.7  12.21  0.001555  ...               0.0  10.69         NaN    NaN
# 126     5.7  33.06  0.004209  ...               1.0   8.76         NaN    NaN
# 127     5.2  35.88  0.004568  ...               1.0  23.59         NaN    NaN
# 128     5.5  38.50  0.004902  ...               1.0  23.53         NaN    NaN
# 129     4.9  45.08  0.005740  ...               1.0  20.77         NaN    NaN
# 130     4.1  33.21  0.004228  ...               1.0   19.7         NaN    NaN
# 131     4.6  34.04  0.004334  ...               1.0  20.74         NaN    NaN
# 132     4.7  30.08  0.003830  ...               1.0   21.2         NaN    NaN
# 133     3.8  17.48  0.002226  ...               1.0  11.23         NaN    NaN
# 134     4.6  23.46  0.002987  ...               0.0   7.03         NaN    NaN
# 135     1.7   5.61  0.000714  ...               0.0   4.84         NaN    NaN
# 136     1.9   6.27  0.000798  ...               1.0   7.35         NaN    NaN
# 137     4.5  20.70  0.002636  ...               0.0  16.85         NaN    NaN
# 138     4.3  16.77  0.002135  ...               0.0  12.36         NaN    NaN
# 139     5.1  16.32  0.002078  ...               0.0  11.78         NaN    NaN
# 140     3.1  15.19  0.001934  ...               0.0  12.21         NaN    NaN
# 141     5.8  34.22  0.004357  ...               0.0  15.38         NaN    NaN
# 142     5.1  20.91  0.002662  ...               0.0  18.06         NaN    NaN
# 143     5.1  26.01  0.003312  ...               0.0   14.6         NaN    NaN
# 144     4.0  21.60  0.002750  ...               0.0  16.33         NaN    NaN
# 145     4.7  16.92  0.002154  ...               0.0  12.27         NaN    NaN
# 146     4.6  13.34  0.001699  ...               0.0   11.7         NaN    NaN
# 148     3.9  15.21  0.001937  ...               0.0   5.96         NaN    NaN
#
#             PKN CorrectionFactor (F)        IsMPa   Is50MPa Unnamed: 25  \
# 124  0.01922544             1.106766  4.899290238  5.422366         NaN
# 125  0.01013412             0.898627  6.518683467  5.857864         NaN
# 126  0.00830448             1.124376  1.972872907  2.218251         NaN
# 127  0.02236332             1.145276  4.895232893  5.606393         NaN
# 128  0.02230644             1.163582  4.550499275  5.294879         NaN
# 129  0.01968996             1.205632  3.430444845  4.135854         NaN
# 130   0.0186756             1.125522  4.416672554  4.971061         NaN
# 131  0.01966152             1.131790  4.536459652  5.134321         NaN
# 132   0.0200976             1.100730  5.247541488  5.776127         NaN
# 133  0.01064604             0.974182   4.78339428  4.659897         NaN
# 134  0.00666444             1.040860  2.231131507  2.322295         NaN
# 135  0.00458832             0.754371  6.423627553  4.845799         NaN
# 136   0.0069678             0.773488  8.728058533  6.751048         NaN
# 137   0.0159738             1.011956  6.060764534  6.133228         NaN
# 138  0.01171728             0.965136  5.487610268  5.296288         NaN
# 139  0.01116744             0.959247  5.374313393  5.155293         NaN
# 140  0.01157508             0.943885  5.984884065  5.649039         NaN
# 141  0.01458024             1.133134  3.346371726  3.791888         NaN
# 142  0.01712088             1.014257  6.430749091  6.522432         NaN
# 143   0.0138408             1.065307   4.17936552  4.452309         NaN
# 144  0.01548084             1.021693  5.628987516  5.751098         NaN
# 145  0.01163196             0.967071  5.399357154  5.221563         NaN
# 146   0.0110916             0.916703  6.530221073  5.986270         NaN
# 148  0.00565008             0.944164  2.917527092  2.754624         NaN
#
#      Piston Area (A)
# 124              NaN
# 125              NaN
# 126              NaN
# 127              NaN
# 128              NaN
# 129              NaN
# 130              NaN
# 131              NaN
# 132              NaN
# 133              NaN
# 134              NaN
# 135              NaN
# 136              NaN
# 137              NaN
# 138              NaN
# 139              NaN
# 140              NaN
# 141              NaN
# 142              NaN
# 143              NaN
# 144              NaN
# 145              NaN
# 146              NaN
# 148              NaN
#
# [24 rows x 27 columns]

# %%
fig = plt.figure(figsize = (8, 4))
widths = [4, 2]
gs = fig.add_gridspec(ncols = 2, nrows = 1, width_ratios = widths)
separate = fig.add_subplot(gs[0])
combined = fig.add_subplot(gs[1])

separate.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
               alpha=0.5)

color = dict(boxes='black', whiskers='black', medians='black', caps='black')
#bp = df.plot.box(color=color,whiskerprops = dict(linestyle='-',linewidth=1.0, color='black'))

box = dict(linewidth = 2.0)
whiskers = dict(linewidth = 2.0)
median = dict(linewidth = 2.0, color = 'k')
caps = dict(linewidth = 2.0)
means = dict(marker = 'o', markeredgecolor = 'k', markerfacecolor = 'k')

separate.boxplot([c1['Is50MPa'], c2['Is50MPa'], c3['Is50MPa'], c4['Is50MPa'], coarse['Is50MPa'], fine['Is50MPa']], meanline = False, showmeans = True, meanprops = means, capprops = caps, medianprops = median, boxprops = box, whiskerprops=whiskers,notch=True, bootstrap=None, widths = 0.5, )
combined.boxplot([carb['Is50MPa'], clast['Is50MPa']], meanline = False, showmeans = True, meanprops = means, capprops = caps, medianprops = median, boxprops = box, whiskerprops=whiskers,notch=True, bootstrap=None, widths = 0.35)

separate.set_ylabel('Point Load Index [MPa]')
separate.set_xticks([1, 2, 3, 4, 5, 6], ['C1', 'C2', 'C3', 'C4', 'Coarse', 'Fine'])

combined.set_xticks([1,2], ['All carb', 'All SS'])
#combined.get_yaxis().set_ticklabels([])
#combined.get_yaxis().set_visible(False)
#combined.get_yaxis().set_ticks([])
combined.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
               alpha=0.5)

combined.yaxis.set_ticklabels([])

separate.set_ylim(0, 8)
combined.set_ylim(0, 8)

plt.tight_layout()

# %%
hfont = {'fontname':'Arial'}

fig = plt.figure(figsize = (8, 4))
widths = [7, 2]
gs = fig.add_gridspec(ncols = 2, nrows = 1, width_ratios = widths)
separate = fig.add_subplot(gs[0])
combined = fig.add_subplot(gs[1])

separate.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
               alpha=0.5)

color = dict(boxes='black', whiskers='black', medians='black', caps='black')
#bp = df.plot.box(color=color,whiskerprops = dict(linestyle='-',linewidth=1.0, color='black'))

box = dict(linewidth = 2.0)
whiskers = dict(linewidth = 2.0)
median = dict(linewidth = 2.0, color = 'k')
caps = dict(linewidth = 2.0)
means = dict(marker = 'o', markeredgecolor = 'k', markerfacecolor = 'k')

separate_violin = separate.violinplot([c1['Is50MPa'], c2['Is50MPa'], c3['Is50MPa'], c4['Is50MPa'], coarse['Is50MPa'], fine['Is50MPa']], showextrema = False)
combined_violin = combined.violinplot([carb['Is50MPa'], clast['Is50MPa']], showextrema = False)

separate.set_ylim(0, 8)
combined.set_ylim(0, 8)

separate.set_ylabel('Point load index [MPa]', fontsize = 16, **hfont)
separate.set_xticks([1, 2, 3, 4, 5, 6], ['C1', 'C2', 'C3', 'C4', 'Coarse', 'Fine'], **hfont)
separate.set_yticks([0, 1, 2, 3, 4, 5, 6, 7, 8], ['0', '1', '2', '3', '4', '5', '6', '7', '8'], **hfont)

separate.tick_params(axis='both', which='major', labelsize=12)
combined.tick_params(axis='both', which='major', labelsize=12)

#separate.set_yticklabels( **hfont)

combined.set_xticks([1,2], ['All carb', 'All SS'], **hfont)
#combined.get_yaxis().set_ticklabels([])
#combined.get_yaxis().set_visible(False)
#combined.get_yaxis().set_ticks([])
combined.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
               alpha=0.5)

combined.yaxis.set_ticklabels([])

iter = 0
for pc in separate_violin['bodies']:
    colors = ['lightblue', 'lightblue', 'lightblue', 'lightblue', 'moccasin', 'moccasin']
    pc.set_facecolor(colors[iter])
    pc.set_edgecolor('black')
    pc.set_linewidth = 2
    pc.set_alpha(1)
    iter += 1

iter = 0
for pc in combined_violin['bodies']:
    colors = ['lightblue', 'moccasin']
    pc.set_facecolor(colors[iter])
    pc.set_edgecolor('black')
    pc.set_linewidth = 2
    pc.set_alpha(1)
    iter += 1
#for partname in ('cbars'):
#    vp = combined_violin[partname]
#    vp.set_edgecolor("k")
#    vp.set_linewidth(2)
def adjacent_values(vals, q1, q3):
    upper_adjacent_value = q3 + (q3 - q1) * 1.5
    upper_adjacent_value = np.clip(upper_adjacent_value, q3, vals[-1])

    lower_adjacent_value = q1 - (q3 - q1) * 1.5
    lower_adjacent_value = np.clip(lower_adjacent_value, vals[0], q1)
    return lower_adjacent_value, upper_adjacent_value


quartile1, medians, quartile3 = np.percentile(c1['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(1, 1 + 1)
separate.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
separate.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
separate.vlines(inds, np.min(c1['Is50MPa']), np.max(c1['Is50MPa']), color='k', linestyle='-', lw=1)


quartile1, medians, quartile3 = np.percentile(c2['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(2, 2 + 1)
separate.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
separate.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
separate.vlines(inds, np.min(c2['Is50MPa']), np.max(c2['Is50MPa']), color='k', linestyle='-', lw=1)

quartile1, medians, quartile3 = np.percentile(c3['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(3, 3 + 1)
separate.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
separate.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
separate.vlines(inds, np.min(c3['Is50MPa']), np.max(c3['Is50MPa']), color='k', linestyle='-', lw=1)

quartile1, medians, quartile3 = np.percentile(c4['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(4, 4 + 1)
separate.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
separate.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
separate.vlines(inds, np.min(c4['Is50MPa']), np.max(c4['Is50MPa']), color='k', linestyle='-', lw=1)

quartile1, medians, quartile3 = np.percentile(coarse['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(5, 5 + 1)
separate.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
separate.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
separate.vlines(inds, np.min(coarse['Is50MPa']), np.max(coarse['Is50MPa']), color='k', linestyle='-', lw=1)

quartile1, medians, quartile3 = np.percentile(fine['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(6, 6 + 1)
separate.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
separate.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
separate.vlines(inds, np.min(fine['Is50MPa']), np.max(fine['Is50MPa']), color='k', linestyle='-', lw=1)




quartile1, medians, quartile3 = np.percentile(carb['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(1, 1 + 1)
combined.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
combined.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
combined.vlines(inds, np.min(carb['Is50MPa']), np.max(carb['Is50MPa']), color='k', linestyle='-', lw=1)


quartile1, medians, quartile3 = np.percentile(clast['Is50MPa'], [25, 50, 75], axis=0)
inds = np.arange(2, 2 + 1)
combined.scatter(inds, medians, marker='^', color='white', s=30, zorder=3)
combined.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
combined.vlines(inds, np.min(clast['Is50MPa']), np.max(clast['Is50MPa']), color='k', linestyle='-', lw=1)

separate.text(0.75, 7.7, 'n = ' + str(len(c1)))
separate.text(1.75, 7.7, 'n = ' + str(len(c2)))
separate.text(2.75, 7.7, 'n = ' + str(len(c3)))
separate.text(3.75, 7.7, 'n = ' + str(len(c4)))
separate.text(4.75, 7.7, 'n = ' + str(len(coarse)))
separate.text(5.75, 7.7, 'n = ' + str(len(fine)))

combined.text(0.75, 7.7, 'n = ' + str(len(carb)))
combined.text(1.75, 7.7, 'n = ' + str(len(clast)))

plt.tight_layout()
fig.savefig('point_load_violins.png', dpi=1000, bbox_inches = "tight")

# %%
quartile3
# Out:
# 5.422366497

# %%
print(len(c1))
print(len(c2))
print(len(c3))
print(len(c4))
print(len(coarse))
print(len(fine))
print(len(carb))
print(len(clast))
# Out:
# 31
# 28
# 18
# 40
# 33
# 24
# 117
# 57

# %%
#significance testing
from scipy.stats import kruskal, mannwhitneyu

kw = kruskal(c1['Is50MPa'], c2['Is50MPa'], c3['Is50MPa'], c4['Is50MPa'], coarse['Is50MPa'], fine['Is50MPa'])
print(kw)
mw = mannwhitneyu(carb['Is50MPa'], clast['Is50MPa'])
print(mw)
# Out:
# KruskalResult(statistic=29.032372346653347, pvalue=2.2850963804598403e-05)
# MannwhitneyuResult(statistic=2200.0, pvalue=0.0002766308295501435)

# %% [markdown]
# Kruskal: p-value is low, so there are differences among some groups. But we don't know yet which ones are different! We should do Dunn's tests for posthoc comparisons among groups, which is easily done in the scikit-posthocs package.
#
# Mann-Whitney U: p-value is low, so the two samples are likely not from the same population

# %%
import scikit_posthocs

# %%
scikit_posthocs.posthoc_dunn([c1['Is50MPa'], c2['Is50MPa'], c3['Is50MPa'], c4['Is50MPa'], coarse['Is50MPa'], fine['Is50MPa']], p_adjust = 'bonferroni')
# Out:
#           1         2         3         4         5         6
# 1  1.000000  1.000000  1.000000  1.000000  1.000000  0.001148
# 2  1.000000  1.000000  0.151974  1.000000  1.000000  0.080844
# 3  1.000000  0.151974  1.000000  0.038011  0.022083  0.000010
# 4  1.000000  1.000000  0.038011  1.000000  1.000000  0.107894
# 5  1.000000  1.000000  0.022083  1.000000  1.000000  0.315251
# 6  0.001148  0.080844  0.000010  0.107894  0.315251  1.000000

# %% [markdown]
# Verdict: not many significant differences here! fine SS from C1 and C3, but that's it! Outcome doesn't change whether I use Bonferroni or Holm p-corrections

# %% [markdown]
# It might be a good idea to make a table of p-values (is this what a correlation matrix is?) for the manuscript
